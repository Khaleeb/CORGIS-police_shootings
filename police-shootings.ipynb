# %% [markdown]
# ## Police Shootings Database
# #### *Caleb Davis*
#
# The CORGIS Police Shootings database doesn't have all the recent reportings, so we'll need to update it by grabbing the most recent csv and cleaning it. Some of the string formatting for dates as well as the way certain columns handle missing values seems a little unintuitive, so I'll try to clean that up a bit as well.
#
# First we'll take a look at the raw csv file I found on the [Washington Post github](https://github.com/washingtonpost/data-police-shootings)

# %%
import csv
import pandas as pd

# %%
pd.read_csv('raw/fatal-police-shootings-data.csv')
# Out:
#         id                     name        date   manner_of_death  \
# 0        3               Tim Elliot  2015-01-02              shot
# 1        4         Lewis Lee Lembke  2015-01-02              shot
# 2        5       John Paul Quintero  2015-01-03  shot and Tasered
# 3        8          Matthew Hoffman  2015-01-04              shot
# 4        9        Michael Rodriguez  2015-01-04              shot
# ...    ...                      ...         ...               ...
# 6134  6695         Dustin Roy Black  2021-03-13              shot
# 6135  6700                      NaN  2021-03-13              shot
# 6136  6701  Douglas William Stroble  2021-03-13              shot
# 6137  6697      Kelly Shannon Bowen  2021-03-14              shot
# 6138  6699       Christopher Ruffin  2021-03-14              shot
#
#                 armed   age gender race           city state  \
# 0                 gun  53.0      M    A        Shelton    WA
# 1                 gun  47.0      M    W          Aloha    OR
# 2             unarmed  23.0      M    H        Wichita    KS
# 3          toy weapon  32.0      M    W  San Francisco    CA
# 4            nail gun  39.0      M    H          Evans    CO
# ...               ...   ...    ...  ...            ...   ...
# 6134              gun  24.0      M    W         Austin    AR
# 6135     undetermined   NaN      M  NaN       Monahans    TX
# 6136              gun  25.0      M  NaN        Wasilla    AK
# 6137  gun and vehicle  51.0      M    W     Reidsville    GA
# 6138              gun  28.0      M    B       Palm Bay    FL
#
#       signs_of_mental_illness  threat_level         flee  body_camera  \
# 0                        True        attack  Not fleeing        False
# 1                       False        attack  Not fleeing        False
# 2                       False         other  Not fleeing        False
# 3                        True        attack  Not fleeing        False
# 4                       False        attack  Not fleeing        False
# ...                       ...           ...          ...          ...
# 6134                    False        attack  Not fleeing        False
# 6135                    False  undetermined          NaN        False
# 6136                    False        attack  Not fleeing        False
# 6137                    False        attack        Other        False
# 6138                    False        attack         Foot        False
#
#       longitude  latitude  is_geocoding_exact
# 0      -123.122    47.247                True
# 1      -122.892    45.487                True
# 2       -97.281    37.695                True
# 3      -122.422    37.763                True
# 4      -104.692    40.384                True
# ...         ...       ...                 ...
# 6134    -91.988    34.981                True
# 6135        NaN       NaN                True
# 6136        NaN       NaN                True
# 6137    -82.110    32.100                True
# 6138    -80.613    28.009                True
#
# [6139 rows x 17 columns]

# %% [markdown]
# This data is already formated pretty well, however there are a few things that could be useful, such as integer dates. Let's clean this up a bit and get it ready for CORGIS. (This code is heavily based on kafura's original script [here](https://github.com/corgis-edu/corgis/blob/master/source/police-shootings/clean-police-shootings.py), I slightly modified some of the string formatting)

# %%
with open('raw/fatal-police-shootings-data.csv', 'r') as rawFile:
    with open('police_shootings-corgis.csv', 'w', encoding='utf-8', newline='') as cleanFile:
        reader = csv.reader(rawFile)
        writer = csv.writer(cleanFile, quotechar='"', quoting=csv.QUOTE_NONNUMERIC, lineterminator='\n')
        
        nameRow = next(reader)
        outRow = [None] * 16
        
        for inpRow in reader:
            # we ignore row[0] since this contains the labels
            
            # We'll organize the data about the victim first
            outRow[0] = str(inpRow[1]) if inpRow[1] != "" else "Unknown" # Name
            
            outRow[1] = int(inpRow[5]) if inpRow[5] != "" else 0 # Age, places 0 if unknown
            
            gender = {"M":"Male", "F":"Female"}
            outRow[2] = gender.get(inpRow[6], "Unknown") # Gender
            
            race = {
                "A":"Asian",
                "B":"African American",
                "W":"White",
                "H":"Hispanic",
                "N":"Native American",
                "O":"Other"
            }
            outRow[3] = race.get(inpRow[7], "Unknown") # Race
            
            
            # Next we'll add the data about the incident Setting
            year, month, day = inpRow[2].split('-')
            
            outRow[4] = int(month) # Month as int
            outRow[5] = int(day) # Day as int
            outRow[6] = int(year) # Year as int
            
            outRow[7] = "{}/{}/{}".format(month, day, year) # full date as string
            
            outRow[8] = str(inpRow[8]) # City
            outRow[9] = str(inpRow[9]) # State
            
            
            # Next we'll add data about the incident Factors
            outRow[10] = str(inpRow[4]) if inpRow[4] != "" else "unknown" # Armed
            outRow[11] = bool(inpRow[10]) # Sign of mental illness
            outRow[12] = str(inpRow[11]) if inpRow[11] != "" else "unknown"# Threat Level
            outRow[13] = str(inpRow[12]) if inpRow[12] != "" else "unknown"# Flee
            outRow[14] = str(inpRow[3]) # manner of death
            outRow[15] = bool(inpRow[13]) # body camera\
            
            # And write to the cleaned up csv
            
            writer.writerow(outRow)

# %% [markdown]
# Now that we have our cleaned up file, let's see how it looks when loaded straight to pandas

# %%
df = pd.read_csv('police_shootings-corgis.csv', header=None)
df
# Out:
#                            0   1     2                 3   4   5     6   \
# 0                  Tim Elliot  53  Male             Asian   1   2  2015
# 1            Lewis Lee Lembke  47  Male             White   1   2  2015
# 2          John Paul Quintero  23  Male          Hispanic   1   3  2015
# 3             Matthew Hoffman  32  Male             White   1   4  2015
# 4           Michael Rodriguez  39  Male          Hispanic   1   4  2015
# ...                       ...  ..   ...               ...  ..  ..   ...
# 6134         Dustin Roy Black  24  Male             White   3  13  2021
# 6135                  Unknown   0  Male           Unknown   3  13  2021
# 6136  Douglas William Stroble  25  Male           Unknown   3  13  2021
# 6137      Kelly Shannon Bowen  51  Male             White   3  14  2021
# 6138       Christopher Ruffin  28  Male  African American   3  14  2021
#
#               7              8   9                10    11            12  \
# 0     01/02/2015        Shelton  WA              gun  True        attack
# 1     01/02/2015          Aloha  OR              gun  True        attack
# 2     01/03/2015        Wichita  KS          unarmed  True         other
# 3     01/04/2015  San Francisco  CA       toy weapon  True        attack
# 4     01/04/2015          Evans  CO         nail gun  True        attack
# ...          ...            ...  ..              ...   ...           ...
# 6134  03/13/2021         Austin  AR              gun  True        attack
# 6135  03/13/2021       Monahans  TX     undetermined  True  undetermined
# 6136  03/13/2021        Wasilla  AK              gun  True        attack
# 6137  03/14/2021     Reidsville  GA  gun and vehicle  True        attack
# 6138  03/14/2021       Palm Bay  FL              gun  True        attack
#
#                13                14    15
# 0     Not fleeing              shot  True
# 1     Not fleeing              shot  True
# 2     Not fleeing  shot and Tasered  True
# 3     Not fleeing              shot  True
# 4     Not fleeing              shot  True
# ...           ...               ...   ...
# 6134  Not fleeing              shot  True
# 6135      unknown              shot  True
# 6136  Not fleeing              shot  True
# 6137        Other              shot  True
# 6138         Foot              shot  True
#
# [6139 rows x 16 columns]

# %% [markdown]
# Great, it looks like our new csv is formatted exactly as we need it for CORGIS! We will add the column headers to the metadata file as such:
# ```
# Victim.Name
# Victim.Age
# Victim.Gender
# Victim.Race
#
# Setting.Date.Month
# Setting.Date.Day
# Setting.Date.Year
# Setting.Date.Full
# Setting.Location.City
# Setting.Location.State
#
# Factors.Armed
# Factors.Mental-Illness
# Factors.Threat-Level
# Factors.Fleeing
# Factors.Manner
# Factors.Body-Cam
# ```

# %%
meta = pd.read_csv('police_shootings-meta.csv', header=None)
meta
# Out:
#                   0                                                  1     2  \
# 0              Name                                   Police Shootings   NaN
# 1           Version                                              0.0.2   NaN
# 2            Author                    Caleb Davis (caldavis@udel.edu)   NaN
# 3           Created                                           03/22/21   NaN
# 4         Data File                        police_shootings-corgis.csv   NaN
# 5          Overview  “The Washington Post is compiling a database o...   NaN
# 6       Data Source  Washington Post Github: https://github.com/was...   NaN
# 7       Description  https://www.washingtonpost.com/national/how-th...   NaN
# 8              Tags  "violence, crime, violent, police, shootings, ...   NaN
# 9               Row                                          Shootings   NaN
# 10  Row Explanation  A fatal shooting that occurred in the US since...   NaN
# 11  Acknowledgement                                                NaN   NaN
# 12             Icon                          police_shootings-icon.png   NaN
# 13           Splash                          police_shootings-icon.png   NaN
# 14       Properties                                               Name  Type
# 15              NaN                                        Victim.Name   str
# 16              NaN                                         Victim.Age   int
# 17              NaN                                      Victim.Gender   str
# 18              NaN                                        Victim.Race   str
# 19              NaN                                 Setting.Date.Month   int
# 20              NaN                                   Setting.Date.Day   int
# 21              NaN                                  Setting.Date.Year   int
# 22              NaN                                  Setting.Date.Full   str
# 23              NaN                              Setting.Location.City   str
# 24              NaN                             Setting.Location.State   str
# 25              NaN                                      Factors.Armed   str
# 26              NaN                             Factors.Mental-Illness  bool
# 27              NaN                               Factors.Threat-Level   str
# 28              NaN                                    Factors.Fleeing   str
# 29              NaN                                     Factors.Manner   str
# 30              NaN                                   Factors.Body-Cam  bool
#
#         3                                                  4
# 0     NaN                                                NaN
# 1     NaN                                                NaN
# 2     NaN                                                NaN
# 3     NaN                                                NaN
# 4     NaN                                                NaN
# 5     NaN                                                NaN
# 6     NaN                                                NaN
# 7     NaN                                                NaN
# 8     NaN                                                NaN
# 9     NaN                                                NaN
# 10    NaN                                                NaN
# 11    NaN                                                NaN
# 12    NaN                                                NaN
# 13    NaN                                                NaN
# 14  Index                                        Description
# 15    NaN  “Full name of the victim, ‘Unknown’ if not rep...
# 16    NaN             “Age of the victim, 0 if not reported”
# 17    NaN  “Gender of victim (‘Male’ or ‘Female’), ‘Unkno...
# 18    NaN  “Race of victim (Asian, African American, Whit...
# 19    NaN          “integer Month in which shooting occured”
# 20    NaN           “integer Day in which shooting occurred”
# 21    NaN           “integer Year in which shooting ocurred”
# 22   TRUE  “string Date (MM/DD/YYYY) in which shooting oc...
# 23    NaN          “Name of City in which shooting occurred”
# 24   TRUE         “Name of State in which shooting occurred”
# 25    NaN  “Description of weapons the victim had, ‘unkno...
# 26    NaN  “True if signs of mental illness were percieve...
# 27    NaN  “Threat of victim as percieved by police, ‘unk...
# 28    NaN  “Means by which the victim was fleeing, or ‘no...
# 29    NaN                         “Manner of victim’s death”
# 30    NaN  “True if a body cam was recording the incident...

# %% [markdown]
# With these two files, CORGIS will be able to produce a proper dataframe with headers:

# %%
df.columns = meta[1][15:]
df
# Out:
# 1                 Victim.Name  Victim.Age Victim.Gender       Victim.Race  \
# 0                  Tim Elliot          53          Male             Asian
# 1            Lewis Lee Lembke          47          Male             White
# 2          John Paul Quintero          23          Male          Hispanic
# 3             Matthew Hoffman          32          Male             White
# 4           Michael Rodriguez          39          Male          Hispanic
# ...                       ...         ...           ...               ...
# 6134         Dustin Roy Black          24          Male             White
# 6135                  Unknown           0          Male           Unknown
# 6136  Douglas William Stroble          25          Male           Unknown
# 6137      Kelly Shannon Bowen          51          Male             White
# 6138       Christopher Ruffin          28          Male  African American
#
# 1     Setting.Date.Month  Setting.Date.Day  Setting.Date.Year  \
# 0                      1                 2               2015
# 1                      1                 2               2015
# 2                      1                 3               2015
# 3                      1                 4               2015
# 4                      1                 4               2015
# ...                  ...               ...                ...
# 6134                   3                13               2021
# 6135                   3                13               2021
# 6136                   3                13               2021
# 6137                   3                14               2021
# 6138                   3                14               2021
#
# 1    Setting.Date.Full Setting.Location.City Setting.Location.State  \
# 0           01/02/2015               Shelton                     WA
# 1           01/02/2015                 Aloha                     OR
# 2           01/03/2015               Wichita                     KS
# 3           01/04/2015         San Francisco                     CA
# 4           01/04/2015                 Evans                     CO
# ...                ...                   ...                    ...
# 6134        03/13/2021                Austin                     AR
# 6135        03/13/2021              Monahans                     TX
# 6136        03/13/2021               Wasilla                     AK
# 6137        03/14/2021            Reidsville                     GA
# 6138        03/14/2021              Palm Bay                     FL
#
# 1       Factors.Armed  Factors.Mental-Illness Factors.Threat-Level  \
# 0                 gun                    True               attack
# 1                 gun                    True               attack
# 2             unarmed                    True                other
# 3          toy weapon                    True               attack
# 4            nail gun                    True               attack
# ...               ...                     ...                  ...
# 6134              gun                    True               attack
# 6135     undetermined                    True         undetermined
# 6136              gun                    True               attack
# 6137  gun and vehicle                    True               attack
# 6138              gun                    True               attack
#
# 1    Factors.Fleeing    Factors.Manner  Factors.Body-Cam
# 0        Not fleeing              shot              True
# 1        Not fleeing              shot              True
# 2        Not fleeing  shot and Tasered              True
# 3        Not fleeing              shot              True
# 4        Not fleeing              shot              True
# ...              ...               ...               ...
# 6134     Not fleeing              shot              True
# 6135         unknown              shot              True
# 6136     Not fleeing              shot              True
# 6137           Other              shot              True
# 6138            Foot              shot              True
#
# [6139 rows x 16 columns]
